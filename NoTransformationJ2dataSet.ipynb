# %%
import pandas as pd
import numpy as np
import math 
import matplotlib.pyplot as plt
df=pd.read_csv('soft2.csv');
df.head(10)
# Out:
#    Time  Fault
# 0     0      0
# 1     1      0
# 2     2      0
# 3     3      0
# 4     4      1
# 5     5      1
# 6     6      1
# 7     7      0
# 8     8      0
# 9     9      0

# %%
length=len(df['Fault'])
sum=0;
for i in range(1,length):
    sum= sum+df['Fault'][i]
    df['Fault'][i]=sum
    #print(sum)
df.head(10)
# Out:
#    Time  Fault
# 0     0      0
# 1     1      0
# 2     2      0
# 3     3      0
# 4     4      1
# 5     5      2
# 6     6      3
# 7     7      3
# 8     8      3
# 9     9      3

# %%
class LinarRegression:
    def __init__ (self,TempDataInput, TempDataFaults):
        self.TempDataInput=TempDataInput
        self.TempDataFaults=TempDataFaults
        self.predictResult=[]
        
    def calculation(self):
        self.mean_x=np.mean(self.TempDataInput)
        self.mean_y=np.mean(self.TempDataFaults)
        print("MeanX and MeanY",self.mean_x,self.mean_y)
        
        self.numer=0.0
        self.dnum=0.0
        
        for i in range(len(self.TempDataInput)):
            self.numer+=(self.TempDataInput[i]-self.mean_x)*(self.TempDataFaults[i]-self.mean_y)
            self.dnum+=(self.TempDataInput[i]-self.mean_x)*(self.TempDataInput[i]-self.mean_x)
            
        self.cof_= self.numer/self.dnum
        self.intercept_=self.mean_y -(self.mean_x*self.cof_)
        
        print(f"Coefficiant {self.cof_}  and intercept {self.intercept_}")
        
        for i in self.TempDataInput:
            self.predictResult.append(i*self.cof_ +self.intercept_)
            
            
    def DrawGraph(self):
        plt.xlabel='Year'
        plt.ylabel='Fault'
        #plt.scatter(df.Year,df.percent,color='RED', marker='+')
        plt.plot(self.TempDataInput,self.TempDataFaults,color='blue',marker='+')
        plt.plot(self.TempDataInput,self.predictResult,color='RED',marker='+')
        
    def NextPrediction(self, start, end, dist):
        ##PredictNext5data Analysis
        self.totalError=0.0;
        for i in range(start,end):
            self.temp= i*self.cof_ +self.intercept_
            self.Error=abs(df['Fault'][i]- self.temp)
            self.totalError+=self.Error

            self.tempP=(self.Error/self.temp)*100
            print("Input =",i,"Ex=",df['Fault'][i]," Pr",'%.2f'%self.temp," Error=",'%.2f'%self.Error," in percent Error",'%.2f'%self.tempP)
        print("\n**Average Error for the Next   ",dist,self.totalError, (self.totalError/dist))

# %%
##10*5
First_TenDataInput=[];
First_TenDataFults=[];
for i in range(1,11):
    First_TenDataInput.append(i)
    First_TenDataFults.append(df['Fault'][i])

l1=LinarRegression(First_TenDataInput,First_TenDataFults);    
l1.calculation()
#l1.DrawGraph()
l1.NextPrediction(11,16,5)
del l1
# Out:
# MeanX and MeanY 5.5 1.8
# Coefficiant 0.42424242424242425  and intercept -0.5333333333333334
# Input = 11 Ex= 4  Pr 4.13  Error= 0.13  in percent Error 3.23
# Input = 12 Ex= 7  Pr 4.56  Error= 2.44  in percent Error 53.59
# Input = 13 Ex= 7  Pr 4.98  Error= 2.02  in percent Error 40.51
# Input = 14 Ex= 11  Pr 5.41  Error= 5.59  in percent Error 103.48
# Input = 15 Ex= 11  Pr 5.83  Error= 5.17  in percent Error 88.67
#
# **Average Error for the Next    5 15.357575757575756 3.0715151515151513

# %%
##20*10
First_20DataInput=[];
First_20DataFults=[];




for i in range(1,21):
    First_20DataInput.append(i)
    First_20DataFults.append(df['Fault'][i])
#print(First_20DataInput,np.mean(First_20DataInput))
l2=LinarRegression(First_20DataInput,First_20DataFults);  
l2.calculation()
#l2.DrawGraph()
l2.NextPrediction(21,31,10)

del l2
# Out:
# MeanX and MeanY 10.5 6.05
# Coefficiant 0.818796992481203  and intercept -2.5473684210526306
# Input = 21 Ex= 14  Pr 14.65  Error= 0.65  in percent Error 4.42
# Input = 22 Ex= 15  Pr 15.47  Error= 0.47  in percent Error 3.01
# Input = 23 Ex= 15  Pr 16.28  Error= 1.28  in percent Error 7.89
# Input = 24 Ex= 15  Pr 17.10  Error= 2.10  in percent Error 12.30
# Input = 25 Ex= 15  Pr 17.92  Error= 2.92  in percent Error 16.31
# Input = 26 Ex= 17  Pr 18.74  Error= 1.74  in percent Error 9.29
# Input = 27 Ex= 17  Pr 19.56  Error= 2.56  in percent Error 13.09
# Input = 28 Ex= 19  Pr 20.38  Error= 1.38  in percent Error 6.77
# Input = 29 Ex= 19  Pr 21.20  Error= 2.20  in percent Error 10.37
# Input = 30 Ex= 21  Pr 22.02  Error= 1.02  in percent Error 4.62
#
# **Average Error for the Next    10 16.31954887218044 1.631954887218044

# %%
##30*15
First_30DataInput=[];
First_30DataFults=[];

for i in range(1,31):
    First_30DataInput.append(i)
    First_30DataFults.append(df['Fault'][i])

l3=LinarRegression(First_30DataInput,First_30DataFults);    
l3.calculation()
#l3.DrawGraph()
l3.NextPrediction(31,46,15)
del l3
# Out:
# MeanX and MeanY 15.5 9.6
# Coefficiant 0.7426028921023359  and intercept -1.910344827586206
# Input = 31 Ex= 22  Pr 21.11  Error= 0.89  in percent Error 4.21
# Input = 32 Ex= 22  Pr 21.85  Error= 0.15  in percent Error 0.67
# Input = 33 Ex= 22  Pr 22.60  Error= 0.60  in percent Error 2.64
# Input = 34 Ex= 23  Pr 23.34  Error= 0.34  in percent Error 1.45
# Input = 35 Ex= 26  Pr 24.08  Error= 1.92  in percent Error 7.97
# Input = 36 Ex= 29  Pr 24.82  Error= 4.18  in percent Error 16.83
# Input = 37 Ex= 29  Pr 25.57  Error= 3.43  in percent Error 13.43
# Input = 38 Ex= 32  Pr 26.31  Error= 5.69  in percent Error 21.63
# Input = 39 Ex= 32  Pr 27.05  Error= 4.95  in percent Error 18.29
# Input = 40 Ex= 36  Pr 27.79  Error= 8.21  in percent Error 29.53
# Input = 41 Ex= 37  Pr 28.54  Error= 8.46  in percent Error 29.66
# Input = 42 Ex= 44  Pr 29.28  Error= 14.72  in percent Error 50.28
# Input = 43 Ex= 45  Pr 30.02  Error= 14.98  in percent Error 49.89
# Input = 44 Ex= 45  Pr 30.76  Error= 14.24  in percent Error 46.27
# Input = 45 Ex= 45  Pr 31.51  Error= 13.49  in percent Error 42.83
#
# **Average Error for the Next    15 96.23893214682984 6.415928809788656

# %%
##40*15
First_40DataInput=[];
First_40DataFults=[];

for i in range(1,41):
    First_40DataInput.append(i)
    First_40DataFults.append(df['Fault'][i])

l4=LinarRegression(First_40DataInput,First_40DataFults);    
l4.calculation()
#l3.DrawGraph()
l4.NextPrediction(41,56,15)
del l4
# Out:
# MeanX and MeanY 20.5 14.025
# Coefficiant 0.8363039399624765  and intercept -3.1192307692307697
# Input = 41 Ex= 37  Pr 31.17  Error= 5.83  in percent Error 18.71
# Input = 42 Ex= 44  Pr 32.01  Error= 11.99  in percent Error 37.48
# Input = 43 Ex= 45  Pr 32.84  Error= 12.16  in percent Error 37.02
# Input = 44 Ex= 45  Pr 33.68  Error= 11.32  in percent Error 33.62
# Input = 45 Ex= 45  Pr 34.51  Error= 10.49  in percent Error 30.38
# Input = 46 Ex= 45  Pr 35.35  Error= 9.65  in percent Error 27.30
# Input = 47 Ex= 45  Pr 36.19  Error= 8.81  in percent Error 24.35
# Input = 48 Ex= 46  Pr 37.02  Error= 8.98  in percent Error 24.25
# Input = 49 Ex= 46  Pr 37.86  Error= 8.14  in percent Error 21.50
# Input = 50 Ex= 46  Pr 38.70  Error= 7.30  in percent Error 18.88
# Input = 51 Ex= 46  Pr 39.53  Error= 6.47  in percent Error 16.36
# Input = 52 Ex= 46  Pr 40.37  Error= 5.63  in percent Error 13.95
# Input = 53 Ex= 46  Pr 41.20  Error= 4.80  in percent Error 11.64
# Input = 54 Ex= 47  Pr 42.04  Error= 4.96  in percent Error 11.80
# Input = 55 Ex= 48  Pr 42.88  Error= 5.12  in percent Error 11.95
#
# **Average Error for the Next    15 121.64962476547842 8.109974984365229

# %%
##150*10
First_40DataInput=[];
First_40DataFults=[];

for i in range(1,151):
    First_40DataInput.append(i)
    First_40DataFults.append(df['Fault'][i])

l4=LinarRegression(First_40DataInput,First_40DataFults);    
l4.calculation()
#l3.DrawGraph()
l4.NextPrediction(151,161,10)
del l4
# Out:
# MeanX and MeanY 75.5 113.38666666666667
# Coefficiant 1.8716565180674694  and intercept -27.923400447427255
# Input = 151 Ex= 218  Pr 254.70  Error= 36.70  in percent Error 14.41
# Input = 152 Ex= 219  Pr 256.57  Error= 37.57  in percent Error 14.64
# Input = 153 Ex= 219  Pr 258.44  Error= 39.44  in percent Error 15.26
# Input = 154 Ex= 219  Pr 260.31  Error= 41.31  in percent Error 15.87
# Input = 155 Ex= 219  Pr 262.18  Error= 43.18  in percent Error 16.47
# Input = 156 Ex= 219  Pr 264.06  Error= 45.06  in percent Error 17.06
# Input = 157 Ex= 219  Pr 265.93  Error= 46.93  in percent Error 17.65
# Input = 158 Ex= 220  Pr 267.80  Error= 47.80  in percent Error 17.85
# Input = 159 Ex= 220  Pr 269.67  Error= 49.67  in percent Error 18.42
# Input = 160 Ex= 221  Pr 271.54  Error= 50.54  in percent Error 18.61
#
# **Average Error for the Next    10 438.1918811206424 43.81918811206424
